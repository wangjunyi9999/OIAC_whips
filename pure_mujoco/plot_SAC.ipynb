# %%
# evaluate distance 2.18， the newest method with oiac
import numpy as np
import matplotlib.pyplot as plt

load_data=np.load("results/SAC.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [-5.55418476  4.09068366 -5.24968606 50.          5.14186962 16.72179502
#  17.89784634 17.72477156 15.27327456 50.         50.         50.
#  50.         50.         50.         -0.13213401 -0.13115194 -0.12891234
#  -0.12864002 -0.12893811 -0.13002937 -0.13011117 -0.13228456 -0.1293108
#  -0.12771462 -0.12876952 -0.13102921 -0.13101631  4.88304237 50.
#  50.         50.         -0.14014968 -0.13957025 -0.13921146 -0.13854653
#  -0.1399164  -0.13720342 -0.1345101  -0.13753068 -0.13830365 -0.13904045
#  -0.13863308 -0.13600748 -0.13755688 -0.1387776  -0.13668175 -2.1667878
#  -0.13885817 -0.13725501 -0.13543508 -0.13397808 -0.13885499 -0.13808794
#  -0.13589891 -0.13563257 -0.13654385 -0.13485975 -0.13622487 12.39686205
#  50.         -0.10747675 -0.10770562 -0.10833937 -0.10769013 -0.10969006
#  16.59267478 -0.15265376 -0.15107136 -0.15017472 -0.15243734 -0.15120311
#  -0.15096071 -0.15108855 -0.1459681  -0.15264866 -0.14905452 -0.15058062
# ...

# %%
# evaluate distance 2.18， the newest method with oiac
import numpy as np
import matplotlib.pyplot as plt

load_data=np.load("results/SAC_oiac.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [ 5.84874659 50.         50.         50.          3.99722911 11.15223321
#  16.99146502 50.         50.         50.         50.         50.
#  50.         -0.12989448 -2.17969649 -0.12599437 24.93404278 50.
#  50.         50.         -0.13740008 -0.13742147 -0.13559899 -0.13458475
#  -0.13751736 -0.1373982  24.94007965 50.         -0.11011901 -0.10849903
#  -0.10906267 -0.10966754 -0.10899022 -0.10909949 -0.10827022 -0.10939075
#  -0.10977611 -0.10941044 -0.10914922 -0.10825448 -0.10953766 -0.10908
#  -0.1090423  -0.10886784 -0.10873711 -0.11031147 -0.10865585 -0.10947475
#  50.         -0.1510616  -0.15234131 -0.15255079 -0.15157739 -0.15246753
#  -0.15188587 -0.15218438 -0.15109537 -0.15164127 -0.14999418 -0.15146807
#   6.11890032 -0.14593706 -0.14441157 -0.14618355 -0.14459386 -0.14510818
#  -0.14387522 -0.14580751 -0.14631815 -0.14656037 -0.14440416 -0.14511166
#  -0.14581534 -0.14324289 -0.14446528 -0.14448417 -0.14544235 -0.14158716
# ...

# %%
# evaluate distance 2.18， the newest method  without oiac
import numpy as np
import matplotlib.pyplot as plt

load_data=np.load("results/SAC.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [ 1.44208269 -4.88810962  5.52741666  6.23167628  4.63968872  8.25726186
#  50.         24.92265331 50.         50.         50.         50.
#  50.         50.         50.         50.         50.         50.
#  50.         50.         50.         50.         -0.10711634 -0.10672836
#  -0.10681137 -0.10579084 -0.10608631 -0.10760571 -0.10602171 -0.10625353
#  -0.10749658 -0.10711041 -0.10891078 -0.10547338 -0.1068359  -0.10603745
#  -0.10664654 -0.10510671 -0.10615791 -0.10531276 -0.1060711  -0.10691645
#  -0.10681281 -0.10602888 -0.10619991  9.91471327 -0.12013276 -0.12199181
#  -0.11974996 -0.12167513 -0.12584442 -0.12276093 -0.12185041 -0.12257053
#  -0.12470825 -0.12310372 -0.11988607 -0.1168589  -0.12079097 -0.11959209
#  -0.11621099 -0.11896627 -0.11774265 -0.11595942 -0.11474087 -0.11693564
#  -0.11685746 -0.13965853 -0.17148252 -0.22543694 -0.30966755 -0.36714323
#  -0.27307534 -0.17699834 -0.13856245 -0.12181556 -0.11481474 -1.79889444
# ...

# %%
# evaluate distance 2.33， the newest method  with oiac
import numpy as np
import matplotlib.pyplot as plt

load_data=np.load("results/SAC.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [ 0.95637292  2.44239068 14.50697696 50.          4.69919598 24.9302156
#   5.45514673  7.79196934  4.50417727 23.01888101 -4.45855608 12.27254491
#  15.88818098  2.8387624  -5.29877257 50.         -6.33246717  1.55285439
#   0.55086303 14.89584189 -0.8253338  -0.7851488  -1.1214116  -1.089152
#  -0.54770455 -1.08898273 -1.45217245 -0.17327126 -0.78492907 -0.47957312
#  -1.18790105 -0.74746007 -0.24762895 -0.53643759 -0.74258609 -1.37131856
#  -0.58639172 12.35481009 -0.23549233 -0.96031699 -0.24487535 -0.2766663
#  -0.61395352 -0.23688217 -0.51444147 -1.05968665]

# %%
# evaluate distance 2.33， the newest method with oiac whole process
import numpy as np
import matplotlib.pyplot as plt

true_load_data=np.load("results/SAC_True_training.npy")
false_load_data=np.load("results/SAC_False_training.npy")
fig=plt.figure(figsize=(10,8))
plt.plot(true_load_data)
plt.plot(false_load_data)

# %%
# evaluate distance 2.33， the newest method  without oiac
import numpy as np
import matplotlib.pyplot as plt

load_data=np.load("results/SAC.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [13.05200343  2.99352832 22.90346625  6.32173351  4.9214225  -1.44893442
#  13.06763983 12.59259808  2.85948332 50.         24.9434273   9.8706177
#  50.         18.73972518  8.22599328 50.         -0.13016189 -0.13409408
#  -0.14778292 -0.15558863 50.         -0.23358627 -0.22049083 -0.20688509
#  -0.21707886 -0.22177101 -0.21910824 -0.19308468 -0.1953094  -0.20412963
#  -0.20556698 -0.21085245 -0.18372317 -0.1795462  -0.17359537 -0.17863703
#  -0.1561878  -0.18439205 21.85723246 50.         -0.1754216  -0.16917101
#  -0.16875722 -0.20457831 -0.18677315 -0.23547753 -0.21627899 -0.2173886
#  -0.20282388]
