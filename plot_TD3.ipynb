# %%
import numpy as np
import matplotlib.pyplot as plt
load_data=np.load("results/TD3_Reacher-v5.npy")
print(load_data)
# Out:
# [-7.24235831e+00 -5.62302212e+00 -7.59413173e+00  2.50000000e+01
#   6.23659736e+00  1.24940342e+01 -3.06570693e-02  3.55422806e+00
#   2.50000000e+01  2.50000000e+01  2.50000000e+01  2.50000000e+01
#   3.56011697e+00 -2.81743022e-02 -1.67769837e-02  2.50000000e+01
#   1.90586667e+00  2.50000000e+01  4.98729911e+00  8.32586372e+00
#   1.24916039e+01  8.32617051e+00  2.50000000e+01  4.15485343e+00
#   1.24941764e+01  2.50000000e+01  4.15347448e+00  1.24931811e+01
#   8.32587829e+00  1.24945033e+01  1.24926843e+01  2.50000000e+01
#   8.32554584e+00  2.50000000e+01  2.50000000e+01  2.50000000e+01
#   1.24941926e+01  2.50000000e+01  2.50000000e+01  2.50000000e+01
#   2.50000000e+01  8.32492703e+00  2.50000000e+01  2.50000000e+01
#   2.50000000e+01  2.50000000e+01  2.50000000e+01  2.50000000e+01
#   2.50000000e+01  2.50000000e+01  2.50000000e+01  1.24943206e+01
#   2.50000000e+01  2.50000000e+01  2.50000000e+01  2.50000000e+01
# ...

# %%
#TD3 with fixed target
fig=plt.figure()
plt.plot(load_data)

# %%
#TD3 test moving target 1
import numpy as np
import matplotlib.pyplot as plt
load_data=np.load("results/TD3_Reacher-v5.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [-6.30226799e+00 -7.13297737e+00 -7.55730240e+00 -7.81659369e+00
#  -2.42245480e-02  2.50000000e+01 -7.54699397e-02 -7.14924209e-02
#  -1.22982517e-01 -1.19479393e-01 -6.99112361e-02 -5.92103071e-02
#  -2.23110491e-01 -6.86851204e-02 -5.48846541e-02 -6.17281690e-02
#   3.11452589e+00  1.24898884e+01 -3.72402179e-01 -8.78382496e-02
#  -3.23018773e-01 -3.26331173e-01 -7.62198625e-02]

# %%
import numpy as np
import matplotlib.pyplot as plt
load_data=np.load("results/TD3_Reacher-v5.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# suppose 1:
# hit quickly or not depend on random target pos
# Out:
# [-6.30968359e+00 -7.12367528e+00 -7.90175186e+00 -3.06904665e+00
#  -3.28595944e-01 -2.58817550e-02  1.24934783e+01 -4.28963013e-01
#  -1.39864201e-01 -1.75432802e-01 -1.76435891e-01 -1.20620374e+00
#  -1.93166683e+00 -1.96713312e+00 -1.97404131e+00 -1.30009594e+00
#  -1.43857595e+00 -1.21136517e+00 -9.12496447e-01 -8.71728751e-01
#  -1.62978657e-01 -2.59542928e-02  4.95938713e+00  1.24948684e+01
#  -8.55366452e-02 -8.76414726e-02 -8.79368156e-02 -1.39107408e-01
#  -1.85147642e-01 -8.29374391e-02 -8.03509275e-02 -7.02925923e-02
#  -2.63088904e-02 -1.21221744e-02  8.32573304e+00 -1.42324744e+00
#  -1.39470160e+00 -1.36630160e+00 -1.32340305e+00 -1.30085853e+00
#  -1.27351514e+00 -1.31539700e+00 -1.19274959e+00 -1.32156308e+00
#  -1.29413028e+00 -1.33406285e+00 -1.29960136e+00 -1.23206073e+00
#  -1.26762514e+00 -1.25679345e+00 -9.83877220e-01 -1.21255926e+00
#  -1.47208130e+00 -1.40930624e+00 -1.42417107e+00 -1.40337944e+00
# ...
