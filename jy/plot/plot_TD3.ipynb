# %%
import numpy as np
import matplotlib.pyplot as plt
# sum(false_load_data[:])#18291->60.97
# sum(true_load_data[:])#20601->68.67
false_load_data=np.load("../results/TD3_False_0_moving_hits.npy")
true_load_data=np.load("../results/TD3_True_0_moving_hits.npy")
fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

false_random_data=np.load("../results/TD3_False_0_moving_training_random.npy")
f_sum_random=false_random_data[-1]
false_load_data=np.load("../results/TD3_False_0_moving_training.npy")+f_sum_random
false_load_data=np.concatenate((false_random_data,false_load_data))

true_random_data=np.load("../results/TD3_True_0_moving_training_random.npy")
t_sum_random=true_random_data[-1]
true_load_data=np.load("../results/TD3_True_0_moving_training.npy")+t_sum_random
true_load_data=np.concatenate((true_random_data,true_load_data))

# value=100
# t_td3=[]
# for i in range(20000):
#     if i%value==0:
#         t_td3.append(sum(true_load_data[i:i+value]))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")

plt.legend()
plt.show()
