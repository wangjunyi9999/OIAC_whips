# %%
import numpy as np
import matplotlib.pyplot as plt
false_load_data=np.load("../results/PPO_False_0_moving_hits.npy")
true_load_data=np.load("../results/PPO_True_0_moving_hits.npy")
fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
sum(false_load_data[:])#35681->118.94
sum(true_load_data[:])#51682->172.28
# Out:
# 35681

# %%
true_load_data=np.load("../results/PPO_True_0_moving_training.npy")
false_load_data=np.load("../results/PPO_False_0_moving_training.npy")


#false_load_data=np.concatenate((false_random_data,false_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
true_load_data=np.load("../results/PPO_True_1_moving_training.npy")
false_load_data=np.load("../results/PPO_False_1_moving_training.npy")


fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
false_load_data=np.load("../results/PPO_False_1_moving_hits.npy")
true_load_data=np.load("../results/PPO_True_1_moving_hits.npy")
fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()
print(sum(false_load_data[:]))#35681->118.94
print(sum(true_load_data[:]))#51682->172.28
# Out:
# 27592
# 17618
