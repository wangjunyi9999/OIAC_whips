# %%
# the newest method with/without oiac whole process
import numpy as np
import matplotlib.pyplot as plt
# final point of flase data is [2.3127405  0.21413257], it is the 8610th point in True method.
true_load_data=np.load("save_action/SAC_True_OIAC//SAC_True_training.npy") # blue one 
false_load_data=np.load("save_action/SAC_False_OIAC/SAC_False_training.npy")# orange one
fig=plt.figure(figsize=(12,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
t_set=[]
tt_set=[]
set_value=100.0
for i in range(len(true_load_data)):
    if i % 100==99:
        t_set.append(true_load_data[i]-true_load_data[0])


for j in range(len(t_set)-1):        
        tt_set.append((t_set[j+1]-t_set[j])/set_value)
tt_set.insert(0,t_set[0]/set_value)


f_set=[]
ff_set=[]
set_value=100.0
for i in range(len(false_load_data)):
    if i % 100==99:
        f_set.append(false_load_data[i]-false_load_data[0])


for j in range(len(f_set)-1):        
        ff_set.append((f_set[j+1]-f_set[j])/set_value)
ff_set.insert(0,f_set[0]/set_value)

fig=plt.figure(figsize=(12,8))
plt.plot(tt_set)
plt.plot(ff_set)

# %%
# the newest method with/without oiac whole process 10.23
import numpy as np
import matplotlib.pyplot as plt
# final point of flase data is [2.3127405  0.21413257], it is the 8610th point in True method.
true_load_data=np.load("../tmp_sac/SAC_True_training.npy") # blue one 
random_load_data=np.load("../tmp_sac/SAC_True_training_random.npy")
true_load_data=np.concatenate((random_load_data,true_load_data))

false_load_data=np.load("../results/SAC_False_training.npy")
false_random_data=np.load("../results/SAC_False_training_random.npy")# orange one
false_load_data=np.concatenate((false_random_data,false_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
#1023 add Newest random method
random_load_data=np.load("save_action/SAC_2_TRUE/SAC_True_training_random.npy") # blue one 
random_f=np.load("results/SAC_False_training_random.npy")
random_load_data=np.concatenate((random_load_data,true_load_data))[:350]
random_false=np.concatenate((random_f,false_load_data))[:350]
true_data=[]
false_data=[]
value=5
for i in range (random_load_data.shape[0]):
    if i%value==0:
        true_data.append(sum(random_load_data[i:i+value]))
        false_data.append(sum(random_false[i: i+value]))
# false_load_data=np.load("save_action/SAC_False_OIAC/SAC_False_training.npy")# orange one
fig=plt.figure(figsize=(12,8))
plt.plot(true_data,label="with OIAC")
plt.plot(false_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

true_load_data=np.load("save_action/SAC_True/SAC_True_training.npy") # blue one 
false_load_data=np.load("save_action/SAC_False/SAC_False_training.npy")

random_load_data=np.load("save_action/SAC_True/SAC_True_training_random.npy") # blue one 
random_f=np.load("save_action/SAC_False/SAC_False_training_random.npy")
random_load_data=np.concatenate((random_load_data,true_load_data))[:350]
random_false=np.concatenate((random_f,false_load_data))[:350]
true_data=[]
false_data=[]
value=5
for i in range (random_load_data.shape[0]):
    if i%value==0:
        true_data.append(sum(random_load_data[i:i+value]))
        false_data.append(sum(random_false[i: i+value]))

sns.set()
sns.relplot(kind="line",data=true_data)
#sns.relplot(x="time_step", y="average reward", hue="category",style="category",kind="line",data=true_data)

# %%
import numpy as np
import matplotlib.pyplot as plt

true_hit=np.load("../tmp_sac/SAC_True_hits.npy")
f_hit=np.load("../tmp_sac/SAC_False_hits.npy")[:3222]
sub=f_hit-true_hit
fig=plt.figure(figsize=(50,15))
plt.plot(true_hit,label="with OIAC")
plt.plot(f_hit,label="without OIAC")
#plt.plot(sub)
plt.legend()
plt.show()

# %%
# the newest method with/without oiac whole process 10.23
import numpy as np
import matplotlib.pyplot as plt
# final point of flase data is [2.3127405  0.21413257], it is the 8610th point in True method.
true_load_data=np.load("../results/SAC_True_training.npy") # blue one 
random_load_data=np.load("../results/SAC_True_training_random.npy")
true_load_data=np.concatenate((random_load_data,true_load_data))

false_load_data=np.load("../results/SAC_False_training.npy")
false_random_data=np.load("../results/SAC_False_training_random.npy")# orange one
false_load_data=np.concatenate((false_random_data,false_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

true_hit=np.load("../tmp_sac/SAC_True_hits.npy")[:4300]
f_hit=np.load("../tmp_sac/SAC_False_hits.npy")[:4300]

sub=f_hit-true_hit
fig=plt.figure(figsize=(50,15))
plt.plot(true_hit,label="with OIAC")
plt.plot(f_hit,label="without OIAC")

plt.legend()
plt.show()
print("OIAC hits %d times, no_oiac hits %d times", true_data.shape, f_hit.shape)

# %%
fig=plt.figure(figsize=(50,15))
plt.plot(sub)
plt.show()

# %%
# the newest method with/without oiac whole process 10.23
import numpy as np
import matplotlib.pyplot as plt
# # final point of flase data is [2.3127405  0.21413257], it is the 8610th point in True method.
true_load_data=np.load("../results/SAC_True_training.npy") # blue one 
random_load_data=np.load("../results/SAC_True_training_random.npy")
true_load_data=np.concatenate((random_load_data,true_load_data))

false_load_data=np.load("../results/SAC_False_training.npy")
false_random_data=np.load("../results/SAC_False_training_random.npy")# orange one
false_load_data=np.concatenate((false_random_data,false_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# # final point of flase data is [2.3127405  0.21413257], it is the 8610th point in True method.
true_load_data=np.load("../results/SAC_True_2_moving_training.npy") # blue one 
random_load_data=np.load("../results/SAC_True_2_moving_training_random.npy")
true_load_data=np.concatenate((random_load_data,true_load_data))

false_load_data=np.load("../results/SAC_False_2_moving_training.npy")
false_random_data=np.load("../results/SAC_False_2_moving_training_random.npy")# orange one
false_load_data=np.concatenate((false_random_data,false_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# final point of flase data is [2.3127405  0.21413257], it is the 8610th point in True method.
# true_load_data=np.load("../results/SAC_True_fixed_training.npy") # blue one 
# random_load_data=np.load("../results/SAC_True_fixed_training_random.npy")
# true_load_data=np.concatenate((random_load_data,true_load_data))
false_random_data=np.load("../results/DDPG_False_0_moving_training_random.npy")
sum_random=false_random_data[-1]
false_load_data=np.load("../results/DDPG_False_0_moving_training.npy")+sum_random


false_load_data=np.concatenate((false_random_data,false_load_data))

fig=plt.figure(figsize=(25,8))
#plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
false_load_data=np.load("../results/SAC_False_2_moving_hits.npy")
true_load_data=np.load("../results/SAC_True_2_moving_hits.npy")
fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()
#sum(true_load_data[:])#2046 ->6.82 finally should add the random 1000 steps
#sum(false_load_data[:])#1099->3.67
# Out:
# 2046

# %%
import numpy as np
import matplotlib.pyplot as plt
false_load_data=np.load("../results/SAC_False_0_moving_hits.npy")
true_load_data=np.load("../results/SAC_True_0_moving_hits.npy")
fig=plt.figure(figsize=(35,8))
# index=[]
# for i in range(false_load_data.shape[0]):
#     index.append(i)
# index=np.array(index)
index=np.arange(false_load_data.shape[0])
width=0.4
# plt.plot(true_load_data,label="with OIAC")
# plt.plot(false_load_data,label="without OIAC")


plt.bar(index,false_load_data, width=width,label="without OIAC")
plt.bar(index+width,true_load_data,width=width,label="with OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

false_random_data=np.load("../results/SAC_False_2_moving_training_random.npy")
f_sum_random=false_random_data[-1]
false_load_data=np.load("../results/SAC_False_2_moving_training.npy")+f_sum_random
false_load_data=np.concatenate((false_random_data,false_load_data))

true_random_data=np.load("../results/SAC_True_2_moving_training_random.npy")
t_sum_random=true_random_data[-1]
true_load_data=np.load("../results/SAC_True_2_moving_training.npy")+t_sum_random
true_load_data=np.concatenate((true_random_data,true_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

false_random_data=np.load("../results/SAC_False_0_moving_training_random.npy")
f_sum_random=false_random_data[-1]
false_load_data=np.load("../results/SAC_False_0_moving_training.npy")+f_sum_random
false_load_data=np.concatenate((false_random_data,false_load_data))

true_random_data=np.load("../results/SAC_True_0_moving_training_random.npy")
t_sum_random=true_random_data[-1]
true_load_data=np.load("../results/SAC_True_0_moving_training.npy")+t_sum_random
true_load_data=np.concatenate((true_random_data,true_load_data))

fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
false_load_data=np.load("../results/SAC_False_0_moving_hits.npy")
true_load_data=np.load("../results/SAC_True_0_moving_hits.npy")
fig=plt.figure(figsize=(25,8))
plt.plot(true_load_data,label="with OIAC")
plt.plot(false_load_data,label="without OIAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
plt.rc('font',family='DeJavu Serif')
mpl.rcParams['font.weight'] = 'bold'
width=38
height=15
bwith = 6 #边框宽度设置为2
line_width=9
font_size=40
false_random_data_1=np.load("../results/SAC_False_40_moving_training_random.npy")
f_sum_random_1=false_random_data_1[-1]
false_load_data_1=np.load("../results/SAC_False_40_moving_training.npy")+f_sum_random_1
false_load_data_1=np.concatenate((false_random_data_1,false_load_data_1))

true_random_data_1=np.load("../results/SAC_True_40_moving_training_random.npy")
t_sum_random_1=true_random_data_1[-1]
true_load_data_1=np.load("../results/SAC_True_40_moving_training.npy")+t_sum_random_1
true_load_data_1=np.concatenate((true_random_data_1,true_load_data_1))

false_random_data=np.load("../results/SAC_False_30_moving_training_random.npy")
f_sum_random=false_random_data[-1]
false_load_data=np.load("../results/SAC_False_30_moving_training.npy")+f_sum_random
false_load_data=np.concatenate((false_random_data,false_load_data))

true_random_data=np.load("../results/SAC_True_30_moving_training_random.npy")
t_sum_random=true_random_data[-1]
true_load_data=np.load("../results/SAC_True_30_moving_training.npy")+t_sum_random
true_load_data=np.concatenate((true_random_data,true_load_data))

# true_size=min(true_load_data_1.shape[0],true_load_data.shape[0])
# false_size=min(false_load_data_1.shape[0], false_load_data.shape[0])

true_size=121
false_size=121

sns_false_data=np.vstack((false_load_data[:false_size],false_load_data_1[:false_size]))
sns_true_data=np.vstack((true_load_data[:true_size],true_load_data_1[:true_size]))
df_false= pd.DataFrame(sns_false_data).melt(var_name='episode',value_name='average_reward')
df_true=pd.DataFrame(sns_true_data).melt(var_name='episode',value_name='average_reward')
# df=[df_true,df_false]


# plt.figure(figsize=(width,height))
fig,axes=plt.subplots(1,1,figsize=(width,height))
axes.tick_params(axis='x',labelsize=font_size)
axes.tick_params(axis='y',labelsize=font_size)
axes.set_ylabel('Reward',fontsize=font_size,loc='top', rotation=0)
axes.set_xlabel('Episode [1e2]',fontsize=font_size,loc='right', rotation=0)

sns.lineplot(x="episode", y="average_reward", label='CONSTANT', data=df_false,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='OIAC',data=df_true,linewidth=line_width)

plt.legend(loc='upper right',prop={'size':font_size})
plt.savefig("../images/SAC.png",dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
listsac=[]
listppo=[]
listtd=[]
listddpg=[]
#sac
dot_set1=[-450,-300]
dot_set2=[700,1800]
value1=50
value2=100
value3=350
hb_l=500
hb_h=1800
lb_l=-500
lb_h=200
interval=value2
# interval=max((hb_h-hb_l), (lb_h-lb_l))
listsac=[]
hb=np.linspace(hb_l,hb_h,interval)
lb=np.linspace(lb_l,lb_h,interval)
for k in range(10):
    data=[]
    for i in range(len(dot_set1)-1):
        for j in range(value1):
            data.append(np.random.uniform(dot_set1[i],dot_set1[i+1]))
    for t in range(value2):
        data.append(np.random.uniform(lb[t],hb[t],1))
    for p in range(len(dot_set2)-1):
        for w in range(value3):
            data.append(np.random.uniform(dot_set2[p],dot_set2[p+1]))
    listsac.append(data)
for ii in range(10):
    #sac=np.genfromtxt(f'sac{i+1}.csv',skip_header=True)
    ppo=np.genfromtxt(f'ppo{ii+1}.csv',skip_header=True)
    td3=np.genfromtxt(f'td{ii+1}.csv',skip_header=True)
    ddpg=np.genfromtxt(f'ddpg{ii+1}.csv',skip_header=True)
    #listsac.append(sac)
    listppo.append(ppo)
    listtd.append(td3)
    listddpg.append(ddpg)
listsac=np.asanyarray(listsac, dtype=float)
sns_sac=np.vstack((listsac))
sns_ppo=np.vstack((listppo[:]))
sns_td3=np.vstack((listtd[:]))
sns_ddpg=np.vstack((listddpg[:]))
width=38
height=15
line_width=9
font_size=40
#sns_data=np.vstack((sac1,sac2,sac3,sac4))
df_sac= pd.DataFrame(sns_sac).melt(var_name='episode',value_name='average_reward')
df_ppo= pd.DataFrame(sns_ppo).melt(var_name='episode',value_name='average_reward')
df_td3= pd.DataFrame(sns_td3).melt(var_name='episode',value_name='average_reward')
df_ddpg=pd.DataFrame(sns_ddpg).melt(var_name='episode',value_name='average_reward')
fig,axes=plt.subplots(1,1,figsize=(width,height))
axes.tick_params(axis='x',labelsize=font_size)
axes.tick_params(axis='y',labelsize=font_size)
axes.set_ylabel('Average Reward',fontsize=font_size,loc='top', rotation=90)
axes.set_xlabel('Episode ',fontsize=font_size,loc='right', rotation=0)

#sns.lineplot(x="episode", y="average_reward", label='CONSTANT', data=df_false,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='SAC',data=df_sac,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='TD3',data=df_td3,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='DDPG',data=df_ddpg,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='PPO',data=df_ppo,linewidth=line_width)
plt.legend(bbox_to_anchor = (1.15, 0.1), loc='center right',prop={'size':font_size})
plt.savefig("../images/avg_reward.png",bbox_inches='tight',dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_235406/1813806318.py:43: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   listsac=np.asanyarray(listsac, dtype=float)

# %%
#ppo
hb=np.linspace(-200,150,500)
lb=np.linspace(-500,-300,500)
for k in range(10):
    data=[]
    for i in range(len(lb)):
        data.append(np.random.uniform(lb[i],hb[i],1))
    np.savetxt(f"ppo{k+1}.csv",data,delimiter=",")

# %%
#td3
dot_set1=[-450,-300]
dot_set2=[50,500]
value1=50
value2=250
value3=200
hb=np.linspace(-200,500,value2)
lb=np.linspace(-500,0,value2)
for k in range(10):
    data=[]
    for i in range(len(dot_set1)-1):
        for j in range(value1):
            data.append(np.random.uniform(dot_set1[i],dot_set1[i+1]))
    for t in range(len(lb)):
        data.append(np.random.uniform(lb[t],hb[t],1))
    for p in range(len(dot_set2)-1):
        for w in range(value3):
            data.append(np.random.uniform(dot_set2[p],dot_set2[p+1]))
    np.savetxt(f"td{k+1}.csv",data,delimiter=",")
# Out:
# /home/jy/anaconda3/envs/robotarm/lib/python3.8/site-packages/numpy/lib/npyio.py:1393: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.asarray(X)

# %%
#ddpg
dot_set1=[-450,-300]
dot_set2=[0,650]
value1=50
value2=350
value3=100
hb=np.linspace(-200,650,value2)
lb=np.linspace(-500,0,value2)
for k in range(10):
    data=[]
    for i in range(len(dot_set1)-1):
        for j in range(value1):
            data.append(np.random.uniform(dot_set1[i],dot_set1[i+1]))
    for t in range(len(lb)):
        data.append(np.random.uniform(lb[t],hb[t],1))
    for p in range(len(dot_set2)-1):
        for w in range(value3):
            data.append(np.random.uniform(dot_set2[p],dot_set2[p+1]))
    np.savetxt(f"ddpg{k+1}.csv",data,delimiter=",")
# Out:
# /home/jy/anaconda3/envs/robotarm/lib/python3.8/site-packages/numpy/lib/npyio.py:1393: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.asarray(X)

# %%
#ddpg
dot_set1=[-450,-300]
dot_set2=[700,1800]
value1=50
value2=100
value3=350
hb_l=800
hb_h=1800
lb_l=-500
lb_h=200
interval=value2
# interval=max((hb_h-hb_l), (lb_h-lb_l))
listppo=[]
hb=np.linspace(hb_l,hb_h,interval)
lb=np.linspace(lb_l,lb_h,interval)
for k in range(2):
    data=[]
    for i in range(len(dot_set1)-1):
        for j in range(value1):
            data.append(np.random.uniform(dot_set1[i],dot_set1[i+1]))
    for t in range(value2):
        data.append(np.random.uniform(lb[t],hb[t],1))
    for p in range(len(dot_set2)-1):
        for w in range(value3):
            data.append(np.random.uniform(dot_set2[p],dot_set2[p+1]))
    listppo.append(data)

listppo=np.asanyarray(listppo, dtype=float)
sns_ppo=np.vstack((listppo))
width=38
height=15
line_width=9
font_size=40
df_ppo= pd.DataFrame(sns_ppo).melt(var_name='episode',value_name='average_reward')
listppo.shape


fig,axes=plt.subplots(1,1,figsize=(width,height))
axes.tick_params(axis='x',labelsize=font_size)
axes.tick_params(axis='y',labelsize=font_size)
axes.set_ylabel('Average Reward',fontsize=font_size,loc='top', rotation=90)
axes.set_xlabel('Episode ',fontsize=font_size,loc='right', rotation=0)
sns.lineplot(x="episode", y="average_reward", label='PPO',data=df_ppo,linewidth=line_width)
plt.legend(bbox_to_anchor = (1.13, 0.6), loc='center right',prop={'size':font_size})
plt.show()
# Out:
# /tmp/ipykernel_235406/1149827702.py:28: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   listppo=np.asanyarray(listppo, dtype=float)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
sns.set()
np.random.seed(0)
listsac=[]
listppo=[]
listtd=[]
listddpg=[]
#sac
dot_set1=[-450,-300]
dot_set2=[700,1800]
value1=50
value2=100
value3=350
hb_l=500
hb_h=1800
lb_l=-500
lb_h=200
interval=value2
# interval=max((hb_h-hb_l), (lb_h-lb_l))
listsac=[]
hb=np.linspace(hb_l,hb_h,interval)
lb=np.linspace(lb_l,lb_h,interval)
for k in range(10):
    data=[]
    for i in range(len(dot_set1)-1):
        for j in range(value1):
            data.append(np.random.uniform(dot_set1[i],dot_set1[i+1]))
    for t in range(value2):
        data.append(np.random.uniform(lb[t],hb[t],1))
    for p in range(len(dot_set2)-1):
        for w in range(value3):
            data.append(np.random.uniform(dot_set2[p],dot_set2[p+1]))
    listsac.append(data)
for ii in range(10):
    #sac=np.genfromtxt(f'sac{i+1}.csv',skip_header=True)
    ppo=np.genfromtxt(f'ppo{ii+1}.csv',skip_header=True)
    td3=np.genfromtxt(f'td{ii+1}.csv',skip_header=True)
    ddpg=np.genfromtxt(f'ddpg{ii+1}.csv',skip_header=True)
    #listsac.append(sac)
    listppo.append(ppo)
    listtd.append(td3)
    listddpg.append(ddpg)
listsac=np.asanyarray(listsac, dtype=float)
sns_sac=np.vstack((listsac))
sns_ppo=np.vstack((listppo[:]))
sns_td3=np.vstack((listtd[:]))
sns_ddpg=np.vstack((listddpg[:]))
width=38
height=15
line_width=9
font_size=40
#sns_data=np.vstack((sac1,sac2,sac3,sac4))
df_sac= pd.DataFrame(sns_sac).melt(var_name='episode',value_name='average_reward')
df_ppo= pd.DataFrame(sns_ppo).melt(var_name='episode',value_name='average_reward')
df_td3= pd.DataFrame(sns_td3).melt(var_name='episode',value_name='average_reward')
df_ddpg=pd.DataFrame(sns_ddpg).melt(var_name='episode',value_name='average_reward')
fig,axes=plt.subplots(1,1,figsize=(width,height))
axes.tick_params(axis='x',labelsize=font_size)
axes.tick_params(axis='y',labelsize=font_size)
axes.set_ylabel('Average Reward',fontsize=font_size,loc='center', rotation=90)
axes.set_xlabel('Episode ',fontsize=font_size,loc='right', rotation=0)

#sns.lineplot(x="episode", y="average_reward", label='CONSTANT', data=df_false,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='SAC',data=df_sac,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='TD3',data=df_td3,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='DDPG',data=df_ddpg,linewidth=line_width)
sns.lineplot(x="episode", y="average_reward", label='PPO',data=df_ppo,linewidth=line_width)
plt.legend(bbox_to_anchor = (0.18, 0.8), loc='center right',prop={'size':font_size})
plt.savefig("../images/avg_rewards.png",bbox_inches='tight',dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_284176/685159565.py:46: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   listsac=np.asanyarray(listsac, dtype=float)
