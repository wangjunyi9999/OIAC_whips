# %%
import numpy as np
import matplotlib.pyplot as plt
load_data=np.load("PPO_d2rl_Reacher-v5_0.npy")
print(load_data)
fig=plt.figure()
plt.plot(load_data)
# Out:
# [-6.78360553 -4.91849237 -5.93155953 -5.26528313 -5.79876635 -6.2756015
#  -6.42406426 -6.15862033 -5.98339651 -6.15821988 -5.39695958 -6.06256945
#  -6.0843032  -6.29808247 -6.17691828 -6.21627433 -6.68332104 -5.54613769
#  -4.96646447 -4.37662314 -6.19537321 -5.98448633 -6.14508642 -5.30869812
#  -5.90447069 -6.4010355  -5.7700228  -4.99822719 -6.46041001 -5.05002661
#  -6.08271916 -6.44017766 -5.56335164 -5.88286069 -6.67343978 -6.19005887]
